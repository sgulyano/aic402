# %% [markdown]
# <a href="https://colab.research.google.com/github/sgulyano/aic402/blob/main/lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIC-402 Lab 6: Apriori Algorithm
#
# CMKL University
#
# By Sarun Gulyanon
#
#
# ### Goal
#
# Explore the application of association rule learning and frequent pattern mining in common scenarios such as market basket analysis.
#
# ### Outline
#
# In this lab, we provide example code for building association rule learning models, such as the Apriori algorithm.
#
# The example uses a transaction dataset of gift purchases for various occasions, the [`Groceries dataset`](http://archive.ics.uci.edu/ml/datasets/Online+Retail). The code examples are implemented using the [`mlxtend`](https://rasbt.github.io/mlxtend/) library.
#
# **Reference**: https://www.geeksforgeeks.org/machine-learning/implementing-apriori-algorithm-in-python/
#
# ----

# %% [markdown]
# ## 1. Import Package and Module

# %%
import warnings
warnings.filterwarnings("ignore", message=r"datetime.datetime.utcnow", module="jupyter_client")

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# ## 2. Load Dataset
#
# In this dataset, each row represents the purchase of a single product within one transaction. Every transaction is identified by a unique `Invoice No.`. The `Description` field specifies the product name, while `Quantity` indicates the number of units purchased in that transaction.
#
# For this lab, we focus only on transactions from Sweden and consider only these three features. We treat each product as one item, and an **itemset** is defined as a collection of items purchased together in the same transaction. Transactions are identified using the `Invoice No.` as the **transaction ID**.

# %%
data = pd.read_excel("https://github.com/sgulyano/aic402/blob/main/Online%20Retail%20Sweden.xlsx?raw=true")
data.drop(['StockCode', 'InvoiceDate', 'UnitPrice', 'CustomerID'], axis=1, inplace=True)
# Clean the Description column: drop rows with null descriptions and convert to string
data.dropna(subset=['Description'], inplace=True)
data['Description'] = data['Description'].astype(str)
# Filter data for Country='Sweden'
data = data[data['Country'] == 'Sweden']
data
# Out:
#     InvoiceNo                        Description  Quantity Country
# 0     C538847    SET OF 3 BABUSHKA STACKING TINS      -240  Sweden
# 1      538848    SET OF 3 BABUSHKA STACKING TINS       240  Sweden
# 2      539338  WORLD WAR 2 GLIDERS ASSTD DESIGNS       576  Sweden
# 3      539338    60 CAKE CASES DOLLY GIRL DESIGN       240  Sweden
# 4      539338     PACK OF 60 SPACEBOY CAKE CASES       240  Sweden
# ..        ...                                ...       ...     ...
# 457    578089      RED TOADSTOOL LED NIGHT LIGHT        12  Sweden
# 458    578089                            POSTAGE         4  Sweden
# 459   C578090                            POSTAGE        -2  Sweden
# 460    580704   VINTAGE DOILY DELUXE SEWING KIT         40  Sweden
# 461   C580702   VINTAGE DOILY DELUXE SEWING KIT        -40  Sweden
#
# [462 rows x 4 columns]

# %% [markdown]
# Transform the data into a binary database, where each column represents an item and each row represents a transaction (`Invoice No.`). Each cell has a value of 1 if the corresponding item was purchased in that transaction, and 0 otherwise.

# %%
basket = data.groupby(['InvoiceNo'])['Description'].apply(list).reset_index()
# Ensure all items within the transaction lists are strings
transactions = [[str(item) for item in transaction] for transaction in basket['Description'].tolist()]
for i in transactions[:10]:
    print(i)
# Out:
# ['SET OF 3 BABUSHKA STACKING TINS']
# ['WORLD WAR 2 GLIDERS ASSTD DESIGNS', '60 CAKE CASES DOLLY GIRL DESIGN', 'PACK OF 60 SPACEBOY CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CAS
AKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES', '36 DOILIES DOLLY GIRL', 'SET OF 36 DOILIES SPACEBOY DESIGN ', 'SET OF 72 PINK HEART PAPER DOILIES', 'MINI PAINT SET VINTAGE ', 'RETROSPOT TEA SET CERAMIC 11 PC ', 'MAGIC DRAWING SLATE PURDEY', 'MAGIC DRAWING SLATE DOLLY GIRL ', 'ASSORTED COLOURS SILK FAN', 'BAG 250g SWIRLY MARBLES', 'SET OF 3 CAKE TINS PANTRY DESIGN ', 'ASSORTED BOTTLE TOP  MAGNETS ', 'VICTORIAN SEWING KIT', 'VINTAGE HEADS AND TAILS CARD GAME ', 'KINGS CHOICE TEA CADDY ', 'TREASURE ISLAND BOOK BOX', 'ABC TREASURE BOOK BOX ']
# ['SET OF 9 HEART SHAPED BALLOONS', 'SET OF 72 PINK HEART PAPER DOILIES', 'PAPER BUNTING RETROSPOT', 'PARTY CONES CANDY ASSORTED', 'PINK BABY BUNTING', 'PACK OF 60 DINOSAUR CAKE CASES', 'POSTAGE']
# ['HAPPY STENCIL CRAFT', 'MONSTERS STENCIL CRAFT', 'BLUE POLKADOT GARDEN PARASOL', 'WOODEN CROQUET GARDEN SET', 'JAM MAKING SET WITH JARS', 'JAM JAR WITH PINK LID', 'CHILDRENS CUTLERY POLKADOT PINK', 'STRAWBERRY LUNCH BOX WITH CUTLERY', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG CARS BLUE', 'LUNCH BAG RED RETROSPOT', 'SET OF 3 BUTTERFLY COOKIE CUTTERS', 'SET OF 20 KIDS COOKIE CUTTERS', '36 FOIL STAR CAKE CASES ', '36 FOIL HEART CAKE CASES', 'SWEETHEART CAKESTAND 3 TIER', 'PAIR PADDED HANGERS PINK CHECK', 'RED RETROSPOT TAPE', 'PLASTERS IN TIN CIRCUS PARADE ', 'WOODEN BOX OF DOMINOES', 'SET/10 BLUE POLKADOT PARTY CANDLES', 'POSTAGE']
# ['LUNCH BAG APPLE DESIGN', 'LUNCH BAG WOODLAND', 'ROUND SNACK BOXES SET OF4 WOODLAND ', 'LUNCH BAG RED RETROSPOT', 'ROUND SNACK BOXES SET OF 4 FRUITS ', 'LUNCH BOX WITH CUTLERY RETROSPOT ', 'WOODEN OWLS LIGHT GARLAND ', 'SET OF 4 PANTRY JELLY MOULDS', 'CHILDRENS CUTLERY DOLLY GIRL ', 'CHILDRENS CUTLERY CIRCUS PARADE', 'CHILDRENS CUTLERY POLKADOT PINK', 'POSTAGE']

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

# %%
df_encoded.head()
# Out:
#    12 PENCIL SMALL TUBE WOODLAND  12 PENCILS SMALL TUBE RED RETROSPOT  \
# 0                          False                                False
# 1                          False                                False
# 2                          False                                False
# 3                          False                                False
# 4                          False                                False
#
#    12 PENCILS SMALL TUBE SKULL  12 PENCILS TALL TUBE WOODLAND  \
# 0                        False                          False
# 1                        False                          False
# 2                        False                          False
# 3                        False                          False
# 4                        False                          False
#
#    3 PIECE SPACEBOY COOKIE CUTTER SET  3 RAFFIA RIBBONS 50'S CHRISTMAS   \
# 0                               False                             False
# 1                               False                             False
# 2                               False                             False
# 3                               False                             False
# 4                                True                             False
#
#    3 RAFFIA RIBBONS VINTAGE CHRISTMAS  3 TIER CAKE TIN RED AND CREAM  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                           True
# 4                               False                          False
#
#    3 TRADITIONAl BISCUIT CUTTERS  SET  36 DOILIES DOLLY GIRL  ...  \
# 0                               False                  False  ...
# 1                               False                   True  ...
# 2                               False                  False  ...
# 3                               False                  False  ...
# 4                               False                  False  ...
#
#    WOODEN STAR CHRISTMAS SCANDINAVIAN  WOODEN TREE CHRISTMAS SCANDINAVIAN  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False
#
#    WOODLAND CHARLOTTE BAG  WOODLAND SMALL RED FELT HEART  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                          False
# 3                   False                          False
# 4                   False                          False
#
#    WORLD WAR 2 GLIDERS ASSTD DESIGNS  WRAP  VINTAGE DOILY   \
# 0                              False                 False
# 1                               True                 False
# 2                              False                 False
# 3                              False                 False
# 4                              False                 False
#
#    WRAP ALPHABET DESIGN  WRAP DOLLY GIRL  WRAP RED VINTAGE DOILY  \
# 0                 False            False                   False
# 1                 False            False                   False
# 2                 False            False                   False
# 3                 False            False                   False
# 4                  True            False                   False
#
#    ZINC WILLIE WINKIE  CANDLE STICK
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
# [5 rows x 261 columns]

# %% [markdown]
# ## 3. Learn Association Rules
#
# The Apriori algorithm follows a breadth-first search (BFS) strategy, exploring itemsets level by level—starting from single items and gradually expanding to larger itemsets. At each level, Apriori prunes infrequent candidates using the *Apriori property*, which states that any superset of an infrequent itemset must also be infrequent. This level-wise BFS exploration significantly reduces the search space and improves efficiency.
#
# Next, we mine association rules using the [`apriori`](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/) algorithm by first computing the frequent itemsets.

# %%
frq_items = apriori(df_encoded, min_support = 0.07, use_colnames = True)

# %%
frq_items.sort_values(['support'], ascending=False)
# Out:
#      support                                           itemsets
# 9   0.521739                                          (POSTAGE)
# 15  0.152174                (SET OF 3 CAKE TINS PANTRY DESIGN )
# 5   0.130435                          (MINI PAINT SET VINTAGE )
# 20  0.130435                       (WOODEN OWLS LIGHT GARLAND )
# 21  0.108696                (WORLD WAR 2 GLIDERS ASSTD DESIGNS)
# 3   0.108696                           (JAM MAKING SET PRINTED)
# 25  0.108696           (RED TOADSTOOL LED NIGHT LIGHT, POSTAGE)
# 11  0.108696                    (RED TOADSTOOL LED NIGHT LIGHT)
# 2   0.108696                                (GUMBALL COAT RACK)
# 22  0.108696                       (GUMBALL COAT RACK, POSTAGE)
# 0   0.086957                  (60 CAKE CASES DOLLY GIRL DESIGN)
# 10  0.086957                               (RABBIT NIGHT LIGHT)
# 8   0.086957                  (PACK OF 72 RETROSPOT CAKE CASES)
# 7   0.086957                   (PACK OF 60 SPACEBOY CAKE CASES)
# 6   0.086957               (PACK OF 60 PINK PAISLEY CAKE CASES)
# 4   0.086957                   (MINI LIGHTS WOODLAND MUSHROOMS)
# 1   0.086957                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 13  0.086957               (ROUND SNACK BOXES SET OF 4 FRUITS )
# 12  0.086957                 (RETROSPOT TEA SET CERAMIC 11 PC )
# 18  0.086957                             (WALL TIDY RETROSPOT )
# 17  0.086957                             (VICTORIAN SEWING KIT)
# 16  0.086957               (SET OF 72 RETROSPOT PAPER  DOILIES)
# 14  0.086957                (SET OF 12 FAIRY CAKE BAKING CASES)
# 19  0.086957                           (WOODEN BOX OF DOMINOES)
# 23  0.086957  (PACK OF 72 RETROSPOT CAKE CASES, PACK OF 60 S...
# 24  0.086957                      (RABBIT NIGHT LIGHT, POSTAGE)
# 26  0.086957                    (WALL TIDY RETROSPOT , POSTAGE)

# %%
print("Total Frequent Itemsets:", frq_items.shape[0])
# Out:
# Total Frequent Itemsets: 27

# %% [markdown]
# Then use the frequent itemsets to generate association rules.

# %%
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)

# %% [markdown]
# ## 4. Rule Evaluation
#
# We evaluate the discovered association rules using multiple metrics, including support, confidence, lift, leverage, and conviction. These measures help quantify how frequently items occur together, the strength of implication between items, and the degree to which the observed co-occurrence differs from random chance.

# %%
rules.drop(['zhangs_metric', 'jaccard',	'certainty', 'kulczynski', 'representativity'], axis=1).sort_values(['confidence', 'lift'], ascending =[False, False]).head(50)
# Out:
#                          antecedents                        consequents  \
# 2  (PACK OF 72 RETROSPOT CAKE CASES)   (PACK OF 60 SPACEBOY CAKE CASES)
# 3   (PACK OF 60 SPACEBOY CAKE CASES)  (PACK OF 72 RETROSPOT CAKE CASES)
# 0                (GUMBALL COAT RACK)                          (POSTAGE)
# 4               (RABBIT NIGHT LIGHT)                          (POSTAGE)
# 6    (RED TOADSTOOL LED NIGHT LIGHT)                          (POSTAGE)
# 8             (WALL TIDY RETROSPOT )                          (POSTAGE)
# 1                          (POSTAGE)                (GUMBALL COAT RACK)
# 7                          (POSTAGE)    (RED TOADSTOOL LED NIGHT LIGHT)
# 5                          (POSTAGE)               (RABBIT NIGHT LIGHT)
# 9                          (POSTAGE)             (WALL TIDY RETROSPOT )
#
#    antecedent support  consequent support   support  confidence       lift  \
# 2            0.086957            0.086957  0.086957    1.000000  11.500000
# 3            0.086957            0.086957  0.086957    1.000000  11.500000
# 0            0.108696            0.521739  0.108696    1.000000   1.916667
# 4            0.086957            0.521739  0.086957    1.000000   1.916667
# 6            0.108696            0.521739  0.108696    1.000000   1.916667
# 8            0.086957            0.521739  0.086957    1.000000   1.916667
# 1            0.521739            0.108696  0.108696    0.208333   1.916667
# 7            0.521739            0.108696  0.108696    0.208333   1.916667
# 5            0.521739            0.086957  0.086957    0.166667   1.916667
# 9            0.521739            0.086957  0.086957    0.166667   1.916667
#
#    leverage  conviction
# 2  0.079395         inf
# 3  0.079395         inf
# 0  0.051985         inf
# 4  0.041588         inf
# 6  0.051985         inf
# 8  0.041588         inf
# 1  0.051985    1.125858
# 7  0.051985    1.125858
# 5  0.041588    1.095652
# 9  0.041588    1.095652

# %% [markdown]
# The results detect co-purchase behavior in the transaction data, such as related cake case items (PACK OF 72 RETROSPOT CAKE CASES and PACK OF 60 SPACEBOY CAKE CASES) exhibit very high confidence and high lift, indicating that they are bought together more frequently than expected by chance, suggesting strong complementary relationships.
#
# Rules involving POSTAGE appear frequently due to its high overall support, where purchasing an item almost always implies postage, but paying postage does not strongly imply purchasing any specific product, highlighting the directional nature of association rules.

# %% [markdown]
# ----
